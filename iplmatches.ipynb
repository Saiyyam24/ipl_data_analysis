# %%
import pandas as pd
import numpy as np

ipl_matches = r"D:\python\flaskapicreation\matches.csv"
matches = pd.read_csv(ipl_matches)

print(matches.head())
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
set(list(matches['team1'])+list(matches['team2']))

# %%
matches.rename(index ={'Rising Pune Supergiant':'Rising Pune Supergiants'},inplace=True)

# %%
matches.replace({'team1': {'Rising Pune Supergiant': 'Rising Pune Supergiants'},
                 'team2': {'Rising Pune Supergiant': 'Rising Pune Supergiants'}}, inplace=True)

# %%
set(list(matches['team1'])+list(matches['team2']))

# %%
matches.replace({
'team1':{'Royal Challengers Bengaluru':'Royal Challengers Bangalore'},
'team2':{'Royal Challengers Bengaluru':'Royal Challengers Bangalore'}
},inplace=True)

# %%
set(list(matches['team1'])+list(matches['team2']))

# %%
matches.replace({'team1':{'Delhi Capitals':'Deccan Chargers'},
                 'teams2':{'Delhi Capitals':'Deccan Chargers'}},inplace=True)

# %%
matches.replace({'team1':{'Delhi Daredevils':'Deccan Chargers'},
                'team2':{'Delhi Daredevils':'Deccan Chargers'}},inplace=True)

# %%
set(list(matches['team1'])+list(matches['team2']))

# %%
matches.replace({'team1':{'Gujarat Lions':'Gujarat Titans'},
                'team2':{'Gujarat Lions':'Gujarat Titans'}},inplace=True)

# %%
matches.replace({'team1':{'Delhi Capitals':'Deccan Chargers'},
                'team2':{'Delhi Capitals':'Deccan Chargers'}},inplace=True)

# %%
set(list(matches['team1'])+list(matches['team2']))

# %%
print(matches.head())

# %%
team1 = "Royal Challengers Bangalore"
team2 = "Mumbai Indians"

temp_df = matches[((matches['team1']==team1) & (matches['team2']==team2))  | ((matches['team1']==team2) & (matches['team2']==team1))]

# %%
total_matches = temp_df.shape[0]
print(total_matches)

# %%
matches_won_team1 = temp_df['winner'].value_counts()[team1]

matches_won_team2 = temp_df['winner'].value_counts()[team2]

print(matches_won_team1)
print(matches_won_team2)

# %%
list(set(matches['player_of_match']))

# %%
team1 = "Royal Challengers Bangalore"
man_of_the_match = set(matches[(matches['team1']==team1) & matches['player_of_match']]['player_of_match'])
print(man_of_the_match)

# %%
# team record
matches.groupby(["player_of_match","team1","team2"]).agg({'target_runs':'sum','player_of_match':'first'})
# Out:
#                                                                          target_runs  \
# player_of_match team1                       team2
# A Chandila      Rajasthan Royals            Pune Warriors                      171.0
# A Kumble        Chennai Super Kings         Royal Challengers Bangalore        127.0
#                 Royal Challengers Bangalore Deccan Chargers                    227.0
# A Manohar       Gujarat Titans              Mumbai Indians                     208.0
# A Mishra        Delhi Daredevils            Deccan Chargers                    195.0
# ...                                                                              ...
# Yuvraj Singh    Pune Warriors               Delhi Daredevils                   188.0
#                 Royal Challengers Bangalore Delhi Daredevils                   187.0
#                                             Kings XI Punjab                    146.0
# ...

# %%
# Out:
#                                     id  \
# winner
# Chennai Super Kings          117910128
# Deccan Chargers               12755873
# Delhi Capitals                61197533
# Delhi Daredevils              43691537
# Gujarat Lions                 13159021
# Gujarat Titans                37753717
# Kings XI Punjab               64417825
# Kochi Tuskers Kerala           3007382
# Kolkata Knight Riders        120520393
# Lucknow Super Giants          32584331
# Mumbai Indians               125636105
# Pune Warriors                  6590335
# Punjab Kings                  31933227
# Rajasthan Royals              96392483
# Rising Pune Supergiant        10826242
# Rising Pune Supergiants        4904811
# Royal Challengers Bangalore   99159373
# Royal Challengers Bengaluru    9979878
# Sunrisers Hyderabad           93668032
#
#                                                                         season  \
# winner
# ...

# %%
matches.replace({
    'team1':{'Royal Challengers Bengaluru':'Royal Challengers Bangalore'},
    'team2':{'Royal Challengers Bengaluru':'Royal Challengers Bangalore'}
},inplace=True)

# %%
matches.groupby('winner').count()
# Out:
#                               id  season  city  date  match_type  \
# winner
# Chennai Super Kings          138     138   131   138         138
# Deccan Chargers               29      29    29    29          29
# Delhi Capitals                48      48    41    48          48
# Delhi Daredevils              67      67    65    67          67
# Gujarat Lions                 13      13    13    13          13
# Gujarat Titans                28      28    28    28          28
# Kings XI Punjab               88      88    79    88          88
# Kochi Tuskers Kerala           6       6     6     6           6
# Kolkata Knight Riders        131     131   128   131         131
# Lucknow Super Giants          24      24    24    24          24
# Mumbai Indians               144     144   139   144         144
# Pune Warriors                 12      12    12    12          12
# Punjab Kings                  24      24    24    24          24
# ...

# %%
print(matches['season'].unique())  # Shows available seasons
# Out:
# ['2007/08' '2009' '2009/10' '2011' '2012' '2013' '2014' '2015' '2016'
#  '2017' '2018' '2019' '2020/21' '2021' '2022' '2023' '2024']

# %%
g = matches.groupby('season')

# %%
g.get_group('2019')
# Out:
#           id season           city        date   match_type  player_of_match  \
# 696  1175356   2019        Chennai  2019-03-23       League  Harbhajan Singh
# 697  1175357   2019        Kolkata  2019-03-24       League       AD Russell
# 698  1175358   2019         Mumbai  2019-03-24       League          RR Pant
# 699  1175359   2019         Jaipur  2019-03-25       League         CH Gayle
# 700  1175360   2019          Delhi  2019-03-26       League        SR Watson
# 701  1175361   2019        Kolkata  2019-03-27       League       AD Russell
# 702  1175362   2019      Bengaluru  2019-03-28       League        JJ Bumrah
# 703  1175363   2019      Hyderabad  2019-03-29       League      Rashid Khan
# 704  1175364   2019     Chandigarh  2019-03-30       League       MA Agarwal
# 705  1175365   2019          Delhi  2019-03-30       League          PP Shaw
# 706  1175366   2019      Hyderabad  2019-03-31       League      JM Bairstow
# ...

# %%
import pandas as pd
matches = pd.read_csv("matches.csv")
matches
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
g = matches.groupby(["team1","team2"])

# %%
m=g.get_group("Mumbai Indians")

# %%
number_of_matches = m.count()
number_of_matches[0]
# Out:
# C:\Users\saiyyam agrawal\AppData\Local\Temp\ipykernel_39444\757599825.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   number_of_matches[0]
# np.int64(123)

# %%
team = "Mumbai Indians"
m = matches[(matches['team1']==team) | (matches['team2']==team)]

# %%
total_matches = m.count()
print(total_matches[0])
# Out:
# 261
# C:\Users\saiyyam agrawal\AppData\Local\Temp\ipykernel_35156\3304749218.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(total_matches[0])

# %%
win = m[m['winner']==team].count()[0]
# Out:
# C:\Users\saiyyam agrawal\AppData\Local\Temp\ipykernel_35156\3087479715.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   win = m[m['winner']==team].count()[0]

# %%
losses = total_matches-win
losses[0]
# Out:
# C:\Users\saiyyam agrawal\AppData\Local\Temp\ipykernel_35156\1119706556.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   losses[0]
# np.int64(117)

# %%
import pandas as pd
matches = pd.read_csv("matches.csv")
matches
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
player = "MS Dhoni"
playerofmatch = matches[matches["player_of_match"]==player]

# %%
number_of_time = len(playerofmatch)
print(f"Number of time  players of the match: {number_of_time}")
# Out:
# Number of time  players of the match: 17

# %%
df = pd.read_csv("deliveries.csv")
p = df.groupby("batter")

# %%
val = p.get_group(player)
val
# total_match = val.groupby("match_id")
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 265       335983       1  Chennai Super Kings              Kings XI Punjab
# 268       335983       1  Chennai Super Kings              Kings XI Punjab
# 269       335983       1  Chennai Super Kings              Kings XI Punjab
# 1719      335989       1  Chennai Super Kings               Mumbai Indians
# 1720      335989       1  Chennai Super Kings               Mumbai Indians
# ...          ...     ...                  ...                          ...
# 259777   1426306       2  Chennai Super Kings  Royal Challengers Bengaluru
# 259780   1426306       2  Chennai Super Kings  Royal Challengers Bengaluru
# 259781   1426306       2  Chennai Super Kings  Royal Challengers Bengaluru
# 259783   1426306       2  Chennai Super Kings  Royal Challengers Bengaluru
# 259784   1426306       2  Chennai Super Kings  Royal Challengers Bengaluru
#
# ...

# %%
df.replace({'team1':{'Rising Pune Supergiant': 'Rising Pune Supergiants'}
                 ,'team2':{'Rising Pune Supergiant': 'Rising Pune Supergiants'}
                 },inplace=True)

# %%
val = p.get_group(player)
set(val["batting_team"])
# Out:
# {'Chennai Super Kings', 'Rising Pune Supergiant', 'Rising Pune Supergiants'}

# %%
s = set(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 s = set(p)
#
# TypeError: unhashable type: 'DataFrame'

# %%
val = p.get_group(player)
val
total_match = val.groupby("match_id")

# %%
len(total_match)
# Out:
# 228

# %%
import pandas as pd
matches = pd.read_csv("matches.csv")
matches
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
player = "P Kumar"
playerofmatch = matches[matches["player_of_match"]==player]
len(playerofmatch)
# Out:
# 2

# %%
playerofmatch = matches[matches["player_of_match"]==player]
p = df.groupby("bowler")
val = p.get_group(player)
val
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 148914   1082643       2    Sunrisers Hyderabad                Gujarat Lions
# 148915   1082643       2    Sunrisers Hyderabad                Gujarat Lions
# 148916   1082643       2    Sunrisers Hyderabad                Gujarat Lions
# 148917   1082643       2    Sunrisers Hyderabad                Gujarat Lions
# 148918   1082643       2    Sunrisers Hyderabad                Gujarat Lions
#
# ...

# %%
list(set(val["bowling_team"]))
# Out:
# ['Gujarat Lions',
#  'Mumbai Indians',
#  'Kings XI Punjab',
#  'Royal Challengers Bangalore',
#  'Sunrisers Hyderabad']
